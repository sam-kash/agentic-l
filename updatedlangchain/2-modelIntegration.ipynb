# %% [markdown]
# ### Model integration -> GROQ, GEMENI, OPENAI

# %%
import os 
from dotenv import load_dotenv
from pathlib import Path
env_path = Path("../.env").resolve()
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from dotenv import load_dotenv
from pathlib import Path
import os

env_path = Path("../.env").resolve()
load_dotenv(env_path, override=True)

print(os.getenv("GROQ_API_KEY")[:8])
# Out:
# gsk_9Mbu

# %%
from langchain.chat_models import init_chat_model
models=init_chat_model("llama-3.3-70b-versatile",
                       model_provider="groq")
models
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.10'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000029620440770>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000296209D8D70>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
# Invoke the model
response = models.invoke("hello how are you ?")
response
# Out:
# AIMessage(content="Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 40, 'total_tokens': 101, 'completion_time': 0.099508352, 'completion_tokens_details': None, 'prompt_time': 0.003231793, 'prompt_tokens_details': None, 'queue_time': 0.161275435, 'total_time': 0.102740145}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f02fb-fc46-7fa2-84b6-fdad752cd9e8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 61, 'total_tokens': 101})

# %%
response.content
# Out:
# "Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?"

# %%
pip install langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# e:\projects 2.0\agentic ai\.venv\Scripts\python.exe: No module named pip

# %%
from dotenv import load_dotenv
from pathlib import Path
import os
from langchain.chat_models import init_chat_model

env_path = Path("../.env").resolve()
load_dotenv(env_path, override=True)

model = init_chat_model(
    "gemini-2.5-flash-lite",
    model_provider="google_genai"
)

response = model.invoke("why do parrots talk?")
response.content
# Out:
# 'Parrots are famous for their ability to mimic sounds, including human speech. This fascinating behavior stems from a combination of biological adaptations and social influences. Here\'s a breakdown of why parrots talk:\n\n**1. Biological Adaptations:**\n\n*   **Vocal Apparatus:** Parrots possess a specialized vocal organ called the **syrinx**, located at the base of their trachea. Unlike the larynx in humans, the syrinx in birds is more complex and allows for a wider range of sound production. Parrots have particularly well-developed syrinxes, enabling them to produce a variety of sounds, including whistles, squawks, and even the nuances of human speech.\n*   **Brain Structure:** Research has shown that parrots have a specialized brain structure that supports vocal learning. They possess a **"shell" region** surrounding their vocal control nuclei, which is thought to be crucial for learning and reproducing complex sounds. This is a key difference from many other bird species that ha
# ...

# %% [markdown]
# ### STREAMING

# %%
for chunk in model.stream("Write me a 200 words paragraph about AI"):
    print(chunk.text , end = " | " , flush= True)
# Out:
# Artificial Intelligence (AI) is |  rapidly transforming our world, moving beyond theoretical concepts to practical applications that touch nearly every aspect of our lives. |  At its core, AI involves the development of computer systems capable of performing tasks that typically require human intelligence, such as learning, problem-solving, decision-making, and even understanding natural language. Machine learning, a subset of AI, allows systems |  to learn from data without explicit programming, leading to advancements in areas like image recognition, predictive analytics, and personalized recommendations. The potential benefits are vast, promising increased efficiency, innovative solutions to complex problems, and enhanced human capabilities. However, this |  progress also raises important ethical considerations regarding bias, job displacement, and data privacy, necessitating careful development and responsible deployment to ensure AI serves humanity beneficially. |  |
