# %% [markdown]
# ### Model integration -> GROQ, GEMENI

# %%
import os 
from dotenv import load_dotenv
from pathlib import Path
env_path = Path("../.env").resolve()
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from dotenv import load_dotenv
from pathlib import Path
import os

env_path = Path("../.env").resolve()
load_dotenv(env_path, override=True)

print(os.getenv("GROQ_API_KEY")[:8])
# Out:
# gsk_9Mbu

# %%
from langchain.chat_models import init_chat_model
models=init_chat_model("llama-3.3-70b-versatile",
                       model_provider="groq")
models
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.10'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000029620440770>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000296209D8D70>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
# Invoke the model
response = models.invoke("hello how are you ?")
response
# Out:
# AIMessage(content="Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 40, 'total_tokens': 101, 'completion_time': 0.099508352, 'completion_tokens_details': None, 'prompt_time': 0.003231793, 'prompt_tokens_details': None, 'queue_time': 0.161275435, 'total_time': 0.102740145}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f02fb-fc46-7fa2-84b6-fdad752cd9e8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 61, 'total_tokens': 101})

# %%
response.content
# Out:
# "Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?"

# %%
pip install langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# e:\projects 2.0\agentic ai\.venv\Scripts\python.exe: No module named pip

# %%
from dotenv import load_dotenv
from pathlib import Path
import os
from langchain.chat_models import init_chat_model

env_path = Path("../.env").resolve()
load_dotenv(env_path, override=True)

model = init_chat_model(
    "gemini-2.5-flash-lite",
    model_provider="google_genai"
)

response = model.invoke("why do parrots talk?")
response.content
# Out:
# 'Parrots talk for a fascinating combination of reasons, primarily driven by their **social nature, intelligence, and vocal learning abilities.** It\'s not just about mimicry; it\'s a complex behavior with evolutionary roots.\n\nHere\'s a breakdown of why parrots talk:\n\n**1. Social Bonding and Communication:**\n\n*   **Flock Communication:** In the wild, parrots are highly social creatures that live in flocks. Vocalizations are crucial for maintaining contact within the group, especially over long distances or when foraging. They use calls to signal danger, locate each other, and coordinate activities.\n*   **Strengthening Bonds:** Mimicking sounds, including those of their flock members, can help strengthen social bonds within the group. It\'s a way of saying "I\'m one of you."\n*   **Understanding Their Environment:** By mimicking sounds, parrots can learn about their surroundings and identify potential threats or food sources.\n\n**2. Vocal Learning Ability:**\n\n*   **Specialized Brain Structures:** Parrots have a unique brain structure called the "song system" that is highly developed for vocal learning. This is similar to the brain structures found in songbirds, which are also adept at learning and producing complex vocalizations.\n*   **"Talking" vs. "Mimicking":** While often referred to as "talking," parrots are technically highly skilled vocal learners and mimics. They can learn to associate certain sounds with specific contexts or rewards, which makes their "talking" more than just random repetition.\n\n**3. Intelligence and Cognitive Skills:**\n\n*   **Problem-Solving and Association:** Parrots are intelligent birds. They can learn to associate specific words or phrases with objects, actions, or people. For example, they might learn to say "hello" when someone enters the room or "cracker" when they want a treat.\n*   **Understanding Context:** Some parrots can even understand the context of their vocalizations. They might use certain phrases appropriately in different situations, demonstrating a rudimentary level of comprehension.\n*   **Attention Seeking:** In captivity, parrots can learn that making sounds gets them attention from their human companions. This can be a powerful motivator for them to vocalize.\n\n**4. Playfulness and Entertainment:**\n\n*   **Curiosity and Exploration:** Parrots are curious creatures. They are fascinated by the sounds around them and enjoy exploring their environment through vocalizations.\n*   **Boredom Relief:** For captive parrots, vocalization can be a way to alleviate boredom and stimulate themselves.\n\n**5. Reproduction and Mating Displays:**\n\n*   **Courtship Rituals:** In some species, complex vocalizations and learned songs play a role in courtship and attracting mates.\n\n**In summary, parrots talk because:**\n\n*   **They are highly social and need to communicate within their groups.**\n*   **They possess exceptional vocal learning abilities thanks to specialized brain structures.**\n*   **They are intelligent and can learn to associate sounds with meaning and context.**\n*   **They are often motivated by attention, play, and curiosity.**\n\nIt\'s important to remember that not all parrots are equally adept at talking, and individual personalities and environmental factors play a significant role. However, the underlying reasons for their vocal talents are deeply rooted in their biology and social evolution.'

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4.1")

response = model.invoke("hello how are you?")
response.content
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 5
#       1 from langchain_openai import ChatOpenAI
#       2
#       3 model = ChatOpenAI(model="gpt-4.1")
#       4
# ----> 5 response = model.invoke("hello how are you?")
#       6 response.content
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1692, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1690     _handle_openai_bad_request(e)
#    1691 except openai.APIError as e:
# -> 1692     _handle_openai_api_error(e)
#    1693 except Exception as e:
#    1694     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1687, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1680         return _construct_lc_result_from_responses_api(
#    1681             response,
#    1682             schema=original_schema_obj,
#    1683             metadata=generation_info,
#    1684             output_version=self.output_version,
#    1685         )
#    1686     else:
# -> 1687         raw_response = self.client.with_raw_response.create(**payload)
#    1688         response = raw_response.parse()
#    1689 except openai.BadRequestError as e:
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\projects 2.0\agentic ai\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
