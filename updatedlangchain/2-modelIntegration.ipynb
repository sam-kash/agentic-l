# %% [markdown]
# ### Model integration -> GROQ, GEMENI

# %%
import os 
from dotenv import load_dotenv
env_path = Path("../.env").resolve()
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from dotenv import load_dotenv
from pathlib import Path
import os

env_path = Path("../.env").resolve()
load_dotenv(env_path, override=True)

print(os.getenv("GROQ_API_KEY")[:8])
# Out:
# gsk_9Mbu

# %%
from langchain.chat_models import init_chat_model
models=init_chat_model("llama-3.3-70b-versatile",
                       model_provider="groq")
models
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.10'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000017729C070E0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000017729C07260>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
# Invoke the model
response = models.invoke("hello how are you ?")
response
# Out:
# AIMessage(content="Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 40, 'total_tokens': 101, 'completion_time': 0.117423687, 'completion_tokens_details': None, 'prompt_time': 0.001742705, 'prompt_tokens_details': None, 'queue_time': 0.160671554, 'total_time': 0.119166392}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019efb18-fefd-7841-868e-ec5bb7682c11-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 61, 'total_tokens': 101})

# %%
response.content
# Out:
# "Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?"

# %%
pip install langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# e:\projects 2.0\agentic ai\.venv\Scripts\python.exe: No module named pip

# %%
from dotenv import load_dotenv
from pathlib import Path
import os
from langchain.chat_models import init_chat_model

env_path = Path("../.env").resolve()
load_dotenv(env_path, override=True)

model = init_chat_model(
    "gemini-2.5-flash-lite",
    model_provider="google_genai"
)

response = model.invoke("why do parrots talk?")
response.content
# Out:
# 'Parrots talk for a fascinating combination of **biological, social, and environmental reasons.** It\'s not just a cute trick; it\'s deeply rooted in their nature. Here\'s a breakdown of why they do it:\n\n**1. Social Bonding and Communication:**\n\n*   **Flock Animals:** Parrots are highly social creatures that live in large flocks in the wild. Communication is vital for their survival and social cohesion. They use a variety of vocalizations to:\n    *   **Maintain contact:** When foraging or flying, they call out to each other to stay in touch and ensure no one gets lost.\n    *   **Warn of danger:** Alarm calls alert the flock to predators.\n    *   **Establish hierarchy and relationships:** Vocalizations can signal dominance, submission, or affection.\n    *   **Coordinate activities:** They might use calls to signal when to move or feed.\n*   **Mimicry as a Social Tool:** In this context, mimicry is a powerful tool for integration. By imitating the calls of their flock mates, they can:\n    *   **Become part of the group:** Learning the "language" of the flock helps them fit in and be accepted.\n    *   **Strengthen bonds:** Mimicking a specific individual can be a sign of recognition and affection.\n\n**2. Biological Predisposition and Brain Structure:**\n\n*   **Vocal Learning:** Parrots are one of the few groups of animals that exhibit true vocal learning. This means they can learn and produce new sounds that aren\'t genetically programmed. This ability is linked to specific brain structures:\n    *   **Vocal Learning Pathway:** Parrots have a specialized neural pathway that is crucial for learning and producing complex sounds. This pathway is similar to what humans have for speech.\n    *   **Larger Brain Regions:** They have larger brain regions dedicated to auditory processing and vocal control compared to many other birds.\n*   **"Talking" vs. "Mimicking":** While often called "talking," what parrots do is more accurately described as **mimicry and vocal learning.** They don\'t understand the semantic meaning of the words they say in the way humans do. However, they can learn to associate sounds with specific contexts or outcomes.\n\n**3. Environmental Factors and Reinforcement:**\n\n*   **Attention and Reward:** In a captive environment, parrots often learn that making sounds, especially human-like sounds, gets them attention from their owners. This attention can be a powerful reward, reinforcing the behavior.\n*   **Association:** Parrots are intelligent and can learn to associate certain sounds with specific events or people. For example, a parrot might learn to say "hello" when someone enters the room or "goodbye" when someone leaves. This is a form of learned association, not necessarily understanding the concept of greeting or farewell.\n*   **Curiosity and Intelligence:** Parrots are highly intelligent and curious birds. They are naturally inclined to explore their environment, and vocalizations are a part of that exploration. They are often trying to figure out what\'s going on around them and may mimic sounds they hear as a way to understand or interact.\n\n**4. In Summary:**\n\nParrots talk because:\n\n*   **They are social creatures** who use vocalizations for communication and bonding in their natural environment.\n*   **They have a biological capacity for vocal learning**, supported by specialized brain structures.\n*   **In captivity, they are often rewarded with attention** for mimicking sounds, and they can learn to associate sounds with specific contexts.\n\nIt\'s important to remember that while parrots can learn to mimic a vast vocabulary, they don\'t possess human-like understanding of language. Their "talking" is a remarkable display of their intelligence, social nature, and their ability to learn and adapt to their environment.'
