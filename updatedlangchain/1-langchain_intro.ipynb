# %% [markdown]
# ### LANGCHAIN VERSION V1

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain import create_agent

agent = agent.creatae(
    model="gpt-5",
    tools= []
    system_prompt = "act as a helpful assistent"
)
agent.run(agent)
