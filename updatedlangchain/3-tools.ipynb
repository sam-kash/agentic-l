# %% [markdown]
# ### TOOLS
#
# models can request to call a tools that perform tasks such as fetching data from dataset, searching web or running code . Tools are
# 1. a schema including the name of the tool, a description and/or an arguement definition (often like json schema)
# 2. a functino or coroutine to execute

# %%
from langchain.tools import tool

@tool
def getWeather(location:str) -> str:
    """Get the weather at a location"""
    return f"its sunny in {location}"

model_wiht.bind_tools([get_weather])

# %% [markdown]
# ### Tool execution loops
